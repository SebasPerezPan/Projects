# %% [markdown]
# Fifth Referee

# %%
from main import select_and_display_season, select_teams, create_versus_from_ids
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a3b97f1e-98d0-4d9a-b03e-8ca4143fabb8">Loading BokehJS ...</span>
#     </div>

# %%
season = select_and_display_season()
# Out:
# Competiciones disponibles:
#
# 1. Premier League    2. Bundesliga    3. Eredivisie    4. La Liga    6. Serie A    7. Primeira Liga
# Selecciona una competición:
#
#  1
# Has seleccionado Premier League
#
# Temporadas disponibles:
#
# 1. 2024/2025
#
# Has seleccionado 2024/2025

# %%
local, away = select_teams(season)
# Out:
# Equipos disponibles en la temporada:
# 1. Liverpool
# 2. Chelsea
# 3. Arsenal
# 4. Nottingham Forest
# 5. Bournemouth
# 6. Aston Villa
# 7. Manchester City
# 8. Newcastle
# 9. Fulham
# 10. Brighton
# 11. Tottenham
# 12. Brentford
# 13. Manchester United
# 14. West Ham
# 15. Everton
# 16. Crystal Palace
# 17. Leicester
# 18. Wolves
# 19. Ipswich
# 20. Southampton
# Selecciona el equipo local:  1
# Selecciona el equipo visitante:  2
# Equipo local seleccionado: Liverpool
# Equipo visitante seleccionado: Chelsea
#
# Liverpool (Liverpool) - Posición: 1, Goles: 37, Goles Concedidos: 16
# Chelsea (London) - Posición: 2, Goles: 37, Goles Concedidos: 19

# %%
if local.city == away.city:
    print("derby")
else:
    print("skr")
print(local.goals_conceded)
print(local.goals)

print(away.goals)

# %%
versus = create_versus_from_ids(season, local, away)

if versus:
    versus.display_analysis()  # Método para mostrar el análisis (por implementar)

# %%
away.display_team_summary()
local.display_team_summary()

# %%
local.display_top_players()
away.display_top_players()

# %%
print(f"\nJugadores del equipo {local.team_name}:")
for idx, player in enumerate(local.players):
    print(f"{idx + 1}. {player.player_name} - Posición: {player.position}")

# Seleccionar un jugador por índice
try:
    selected_player_idx = int(input("Selecciona un jugador (por número): ")) - 1
    selected_player = local.players[selected_player_idx]
    
    print(f"\nJugador seleccionado: {selected_player.player_name}")
    
    # Mostrar estadísticas detalladas del jugador
    selected_player.display_detailed_stats(connection)
    
except IndexError:
    print("Seleccionaste un número fuera del rango. Por favor, inténtalo de nuevo.")
except ValueError:
    print("Entrada inválida. Por favor, ingresa un número.")

# %%
print(f"\nJugadores del equipo {selected_secondary_team.team_name}:")
for idx, player in enumerate(selected_secondary_team.players):
    print(f"{idx + 1}. {player.player_name} - Posición: {player.position}")

# Seleccionar un jugador por índice
try:
    selected_player_idx = int(input("Selecciona un jugador (por número): ")) - 1
    selected_player = selected_secondary_team.players[selected_player_idx]
    
    print(f"\nJugador seleccionado: {selected_player.player_name}")
    
    # Mostrar estadísticas detalladas del jugador
    selected_player.display_detailed_stats(connection)
    
except IndexError:
    print("Seleccionaste un número fuera del rango. Por favor, inténtalo de nuevo.")
except ValueError:
    print("Entrada inválida. Por favor, ingresa un número.")
