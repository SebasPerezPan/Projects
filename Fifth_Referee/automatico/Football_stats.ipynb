# %% [markdown]
# Fifth Referee

# %%
from main import select_and_display_season, select_teams
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e7677894-fe20-499e-a4e6-08528fcb3426">Loading BokehJS ...</span>
#     </div>

# %%
season = select_and_display_season()
# Out:
# Competiciones disponibles:
#
# 1. La Liga    2. Premier League    3. Bundesliga    4. Ligue 1    5. Serie A    6. Primeira Liga
# Selecciona una competición:
#
#  1
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/js_callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
# Has seleccionado La Liga
#
# Temporadas disponibles:
#
# 1. 2024/2025
#
# Has seleccionado 2024/2025
# ...

# %%
local, away = select_teams(season)
# Out:
# Equipos disponibles en la temporada:
# 1. Real Madrid
# 2. FC Barcelona
# 3. Villarreal CF
# 4. Atlético de Madrid
# 5. Sevilla FC
# 6. RCD Espanyol
# 7. Valencia CF
# 8. Getafe CF
# 9. Real Valladolid
# 10. RCD Mallorca
# 11. Osasuna
# 12. Athletic Club
# 13. Real Betis
# 14. Real Sociedad
# 15. Celta de Vigo
# 16. Las Palmas
# 17. Alavés
# 18. Rayo Vallecano
# 19. Girona FC
# 20. CD Leganés
# Selecciona el equipo principal (por número):  2
# Selecciona el equipo secundario (por número):  1
# Equipo local seleccionado: FC Barcelona
# Equipo visitante seleccionado: Real Madrid

# %%
away.display_team_summary()
local.display_team_summary()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d9fb51bc-6b03-4ae7-b865-71b6e6b1cb04">Loading BokehJS ...</span>
#     </div>
#   <div id="d7327049-17bf-48cb-87cd-bf4aa80ae0bb" data-root-id="p1292" style="display: contents;"></div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="df31f537-5eab-4286-98f2-5adf9a13fde2">Loading BokehJS ...</span>
#     </div>
# ...

# %%
local.display_top_players()
away.display_top_players()

# %%
print(f"\nJugadores del equipo {selected_main_team.team_name}:")
for idx, player in enumerate(selected_main_team.players):
    print(f"{idx + 1}. {player.player_name} - Posición: {player.position}")

# Seleccionar un jugador por índice
try:
    selected_player_idx = int(input("Selecciona un jugador (por número): ")) - 1
    selected_player = selected_main_team.players[selected_player_idx]
    
    print(f"\nJugador seleccionado: {selected_player.player_name}")
    
    # Mostrar estadísticas detalladas del jugador
    selected_player.display_detailed_stats(connection)
    
except IndexError:
    print("Seleccionaste un número fuera del rango. Por favor, inténtalo de nuevo.")
except ValueError:
    print("Entrada inválida. Por favor, ingresa un número.")

# %%
print(f"\nJugadores del equipo {selected_secondary_team.team_name}:")
for idx, player in enumerate(selected_secondary_team.players):
    print(f"{idx + 1}. {player.player_name} - Posición: {player.position}")

# Seleccionar un jugador por índice
try:
    selected_player_idx = int(input("Selecciona un jugador (por número): ")) - 1
    selected_player = selected_secondary_team.players[selected_player_idx]
    
    print(f"\nJugador seleccionado: {selected_player.player_name}")
    
    # Mostrar estadísticas detalladas del jugador
    selected_player.display_detailed_stats(connection)
    
except IndexError:
    print("Seleccionaste un número fuera del rango. Por favor, inténtalo de nuevo.")
except ValueError:
    print("Entrada inválida. Por favor, ingresa un número.")
